# %%
bike={
    'model':['ronin','spshine','xtreme','hunter350'],
    'prices':[126000,72900,90676,137648],
    'brand':['tvs','honda','hero','royalEnfild'],
    'usages':['dailyRide','commuter','dailyride','dailyride'],
    'average':[42,65,65,40]
}
print(Bike)
# Out:
# {'Model': ['Ronin', 'SpShine', 'Xtreme', 'Hunter350'], 'Prices': [126000, 72900, 90676, 137648], 'brand': ['TVS', 'Honda', 'Hero', 'RoyalEnfild'], 'Usages': ['DailyRide', 'Commuter', 'DailyRide', 'DailyRide'], 'Average': [42, 65, 65, 40]}

# %%
print(bike['model'])
# Out:
# ['ronin', 'spshine', 'xtreme', 'hunter350']

# %%
print(bike['brand'][2])
# Out:
# hero

# %%
print(bike['average'][3])
# Out:
# 40
