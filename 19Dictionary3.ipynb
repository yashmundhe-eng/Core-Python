# %%
player={
  'name':'Virat kholi',
   'personal':{
      'age':37,
      'gender':'male',
      'country':'india'
  },
  'professional':{
      'position':'Top order batter',
      'frechicy':'Royal Challengers Banglor',
      'jersey':18
  },
  'health':{
      'height':175,
      'weight':69
  }
}
print(player)
# Out:
# {'name': 'Virat kholi', 'personal': {'age': 37, 'gender': 'male', 'country': 'india'}, 'professional': {'position': 'Top order batter', 'frechicy': 'Royal Challengers Banglor', 'jersey': 18}, 'health': {'height': 175, 'weight': 69}}

# %%
print(player['name'])
# Out:
# Virat kholi

# %%
print(player['professional'])
# Out:
# {'position': 'Top order batter', 'frechicy': 'Royal Challengers Banglor', 'jersey': 18}

# %%
print(player['professional']['frechicy'])
# Out:
# Royal Challengers Banglor
