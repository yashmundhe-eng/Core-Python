# %%
car={
    "brand":"MG",
    "model":"hector",
    "product":"SUV",
    "price":"1950000",
    "paymentmode":"UPI"
}
print(car)
# Out:
# {'brand': 'MG', 'model': 'hector', 'product': 'SUV', 'price': '1950000', 'paymentmode': 'UPI'}

# %%
print(car.keys())
# Out:
# dict_keys(['brand', 'model', 'product', 'price', 'paymentmode'])

# %%
for k in car.keys():
  print(k.upper())
# Out:
# BRAND
# MODEL
# PRODUCT
# PRICE
# PAYMENTMODE

# %%
print(car.values())
# Out:
# dict_values(['MG', 'hector', 'SUV', '1950000', 'UPI'])

# %%
for v in car.values():
  print(v)
# Out:
# MG
# hector
# SUV
# 1950000
# UPI

# %%
for v in car.items():
  print(v)
# Out:
# ('brand', 'MG')
# ('model', 'hector')
# ('product', 'SUV')
# ('price', '1950000')
# ('paymentmode', 'UPI')
