# %%
exam={}.fromkeys(['science','maths','english'],1)
print(exam)
# Out:
# {'science': 1, 'maths': 1, 'english': 1}

# %%
exam['english']+=3
print(exam)
# Out:
# {'science': 1, 'maths': 1, 'english': 4}

# %%
exam['science']+=84
print(exam)
# Out:
# {'science': 85, 'maths': 1, 'english': 4}

# %%
student={}.fromkeys(['yash','sumit','piyush','ritika',], "Amravati")
print(student)
# Out:
# {'yash': 'Amravati', 'sumit': 'Amravati', 'piyush': 'Amravati', 'ritika': 'Amravati'}

# %%
student["piyush"]='pusad'
print(student)
# Out:
# {'yash': 'Amravati', 'sumit': 'Amravati', 'piyush': 'pusad', 'ritika': 'Amravati'}

# %%
student["piyush"]='pusad'
print(student)
# Out:
# {'yash': 'pusad', 'sumit': 'Amravati', 'piyush': 'pusad', 'ritika': 'Amravati'}

# %%
student["yash"]='pusad'
print(student)
# Out:
# {'yash': 'pusad', 'sumit': 'Amravati', 'piyush': 'pusad', 'ritika': 'Amravati'}
